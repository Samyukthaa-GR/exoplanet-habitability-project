# %%
import pandas as pd

df_baseline = pd.read_csv("../data/processed/exoplanet_baseline_cleaned.csv")
df_physics = pd.read_csv("../data/processed/exoplanet_physics_cleaned.csv")

# %%
print("Baseline shape:", df_baseline.shape)
print("Physics shape:", df_physics.shape)
# Out:
# Baseline shape: (1877, 7)
# Physics shape: (879, 7)

# %%
df.describe()
# Out:
#           pl_rade  pl_orbsmax       st_teff      st_lum  teq_recalc
# count  872.000000  879.000000    879.000000  879.000000  879.000000
# mean     8.410311    3.716394   6063.796883    0.433155    2.330022
# std      6.518976   43.129195   1512.235801    0.422414    1.366896
# min      0.668000    0.006000   3787.000000    0.000870    0.017819
# 25%      2.299000    0.052395   5751.500000    0.187325    1.278863
# 50%      8.322330    0.094800   5968.000000    0.346000    2.266482
# 75%     13.597370    0.250145   6180.000000    0.536825    3.303049
# max     77.342100  773.000000  29300.000000    3.800000   13.941487

# %%
import matplotlib.pyplot as plt

plt.hist(df['pl_rade'], bins=50)
plt.title("Planet Radius Distribution")
plt.xlabel("Earth Radii")
plt.ylabel("Count")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.hist(df['teq_recalc'], bins=50)
plt.title("Planet Radius Distribution")
plt.xlabel("Earth Radii")
plt.ylabel("Count")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.hist(df['st_lum'], bins=50)
plt.title("Planet Radius Distribution")
plt.xlabel("Earth Radii")
plt.ylabel("Count")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.hist(df['pl_orbsmax'], bins=50)
plt.title("Planet Radius Distribution")
plt.xlabel("Earth Radii")
plt.ylabel("Count")
plt.show()
