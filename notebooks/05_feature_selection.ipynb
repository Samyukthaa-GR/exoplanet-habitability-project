# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/processed/modeling_dataset_v1.csv")

# %%
df.select_dtypes(include=np.number).columns
# Out:
# Index(['pl_rade', 'pl_orbsmax', 'st_teff', 'st_lum', 'teq_recalc',
#        'st_lum_linear', 'habitable'],
#       dtype='str')

# %%
df = df.drop(columns=["st_lum"])

# %%
df.columns
# Out:
# Index(['pl_name', 'hostname', 'pl_rade', 'pl_orbsmax', 'st_teff', 'teq_recalc',
#        'st_lum_linear', 'habitable'],
#       dtype='str')
